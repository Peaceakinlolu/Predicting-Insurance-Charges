# %% [markdown]
# ![](image.jpg)
#
#
# Dive into the heart of data science with a project that combines healthcare insights and predictive analytics. As a Data Scientist at a top Health Insurance company, you have the opportunity to predict customer healthcare costs using the power of machine learning. Your insights will help tailor services and guide customers in planning their healthcare expenses more effectively.
#
# ## Dataset Summary
#
# Meet your primary tool: the `insurance.csv` dataset. Packed with information on health insurance customers, this dataset is your key to unlocking patterns in healthcare costs. Here's what you need to know about the data you'll be working with:
#
# ## insurance.csv
# | Column    | Data Type | Description                                                      |
# |-----------|-----------|------------------------------------------------------------------|
# | `age`       | int       | Age of the primary beneficiary.                                  |
# | `sex`       | object    | Gender of the insurance contractor (male or female).             |
# | `bmi`       | float     | Body mass index, a key indicator of body fat based on height and weight. |
# | `children`  | int       | Number of dependents covered by the insurance plan.              |
# | `smoker`    | object    | Indicates whether the beneficiary smokes (yes or no).            |
# | `region`    | object    | The beneficiary's residential area in the US, divided into four regions. |
# | `charges`   | float     | Individual medical costs billed by health insurance.             |
#
#
#
# A bit of data cleaning is key to ensure the dataset is ready for modeling. Once your model is built using the `insurance.csv` dataset, the next step is to apply it to the `validation_dataset.csv`. This new dataset, similar to your training data minus the `charges` column, tests your model's accuracy and real-world utility by predicting costs for new customers.
#
# ## Let's Get Started!
#
# This project is your playground for applying data science in a meaningful way, offering insights that have real-world applications. Ready to explore the data and uncover insights that could revolutionize healthcare planning? Let's begin this exciting journey!

# %% [markdown]
# ## Import Libraries & Data

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, KFold

# Loading the insurance dataset
insurance_data_path = 'insurance.csv'
insurance = pd.read_csv(insurance_data_path)
insurance.head()
# Out:
#     age     sex     bmi  children smoker     region       charges
# 0  19.0  female  27.900       0.0    yes  southwest     16884.924
# 1  18.0    male  33.770       1.0     no  Southeast     1725.5523
# 2  28.0    male  33.000       3.0     no  southeast     $4449.462
# 3  33.0    male  22.705       0.0     no  northwest  $21984.47061
# 4  32.0    male  28.880       0.0     no  northwest    $3866.8552

# %% [markdown]
# ## Data Exploration

# %%
# Checking the columns
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1272 non-null   float64
#  1   sex       1272 non-null   object
#  2   bmi       1272 non-null   float64
#  3   children  1272 non-null   float64
#  4   smoker    1272 non-null   object
#  5   region    1272 non-null   object
#  6   charges   1284 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 73.3+ KB

# %%
# Checking the DataFrame of missing values
missing = insurance[insurance.isna().any(axis=1)]
missing.head(10)
# Out:
#      age     sex     bmi  children smoker     region      charges
# 23 -34.0  female     NaN       1.0    yes        NaN  $37701.8768
# 32   NaN     NaN  28.600       NaN    NaN  Southwest         $nan
# 43  37.0  female     NaN       NaN    NaN  southeast     6313.759
# 44   NaN    male     NaN       NaN     no        NaN          NaN
# 49   NaN     NaN     NaN       1.0    NaN        NaN          NaN
# 51  21.0     NaN     NaN       2.0    NaN  Northwest   $3579.8287
# 58   NaN     NaN  22.880       NaN    yes        NaN   23244.7902
# 63   NaN  female  25.935       1.0    NaN  Northwest   4133.64165
# 65   NaN     NaN  28.900       NaN    NaN  Southwest     1743.214
# 76   NaN       F     NaN       1.0     no  Southeast         $nan

# %%
insurance.isna().sum().sort_values()
# Out:
# charges     54
# age         66
# sex         66
# bmi         66
# children    66
# smoker      66
# region      66
# dtype: int64

# %% [markdown]
# ### Dealing with the missing Data

# %%
# Finding the threshold
threshold = len(insurance) * 0.05
# Finding the columns to drop
cols_to_drop = insurance.columns[insurance.isna().sum() <= threshold]

insurance_clean = insurance.dropna(subset=cols_to_drop)

# %%
# Checking for further missing values
insurance_clean.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ### Checking each Column and Cleaning it

# %%
insurance_clean["age"].dtype
# Out:
# dtype('float64')

# %%
# Converting the column to int
insurance_clean["age"] = insurance_clean["age"].astype("int")
insurance_clean["age"].describe()
# Out:
# count    1208.000000
# mean       35.355960
# std        22.061241
# min       -64.000000
# 25%        24.750000
# 50%        38.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
# Filtering for columns with positive values
insurance_clean = insurance_clean.loc[insurance_clean["age"] > 0, :]
insurance_clean["age"].describe()
# Out:
# count    1149.000000
# mean       39.204526
# std        14.163214
# min        18.000000
# 25%        26.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
# Checking the sex column
insurance_clean["sex"].dtype
# Out:
# dtype('O')

# %%
# Checking the categories
insurance_clean["sex"] = insurance_clean["sex"].str.strip()
insurance_clean["sex"].value_counts()
# Out:
# male      471
# female    457
# M          58
# woman      56
# man        54
# F          53
# Name: sex, dtype: int64

# %%
# Replacing wrong categories
categories = {"M":"male", "woman":"female", "man":"male", "F":"female"}
insurance_clean["sex"] = insurance_clean["sex"].replace(categories)
insurance_clean["sex"].value_counts(dropna=False)
# Out:
# male      583
# female    566
# Name: sex, dtype: int64

# %%
# Checking the bmi column
insurance_clean["bmi"].dtype
# Out:
# dtype('float64')

# %%
insurance_clean["bmi"].describe()
# Out:
# count    1149.000000
# mean       30.592620
# std         6.124013
# min        15.960000
# 25%        26.200000
# 50%        30.300000
# 75%        34.700000
# max        53.130000
# Name: bmi, dtype: float64

# %%
# Checking the children column
insurance_clean["children"].dtype
# Out:
# dtype('float64')

# %%
# Correcting the data type
insurance_clean["children"] = insurance_clean["children"].astype("int")
insurance_clean["children"].dtype
# Out:
# dtype('int64')

# %%
insurance_clean["children"].describe()
# Out:
# count    1149.000000
# mean        0.947781
# std         1.314243
# min        -4.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
# Introducing the lower bound
insurance_clean["children"] = insurance_clean["children"].clip(lower=0)
insurance_clean["children"].describe()
# Out:
# count    1149.000000
# mean        1.017406
# std         1.192183
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
# Checking the smoker column
insurance_clean["smoker"].dtype
# Out:
# dtype('O')

# %%
insurance_clean["smoker"].value_counts(dropna=False)
# Out:
# no     912
# yes    237
# Name: smoker, dtype: int64

# %%
# Checking the region column
insurance_clean["region"].dtype
# Out:
# dtype('O')

# %%
insurance_clean["region"].value_counts(dropna=False)
# Out:
# Southeast    160
# southeast    148
# southwest    147
# Northeast    142
# northwest    141
# Northwest    141
# northeast    138
# Southwest    132
# Name: region, dtype: int64

# %%
insurance_clean["region"] = insurance_clean["region"].str.strip().str.lower()
insurance_clean["region"].value_counts()
# Out:
# southeast    308
# northwest    282
# northeast    280
# southwest    279
# Name: region, dtype: int64

# %%
# Checking the charges column
insurance_clean["charges"].dtype
# Out:
# dtype('O')

# %%
insurance_clean["charges"].sum()
# Out:
# '16884.9241725.5523$4449.462$21984.47061$3866.85528240.58967281.5056$6406.410728923.13692$2721.320827808.72511826.84311090.71781837.23710797.336210602.38536837.46713228.846954149.7361137.011$6203.9017514001.1338$14451.8351512268.632252775.1921538711.035585.5762198.18985$13770.097951194.55914$1625.4337515612.193352302.339774.276348173.3613046.0624949.75876272.477220630.283513393.356353556.922312629.89672211.13075$23568.272$37742.57578059.679147496.4944513607.3687534303.16725989.523658606.21744504.662430166.6181714711.743814235.0726389.37785$5920.104117663.1442$16577.77956799.45811741.72611946.62597726.85411356.66091532.46974441.213157935.2911537165.163811033.6617$39836.51921098.5540543578.939411073.1768026.666611082.5772$2026.974110942.1320530184.936747291.055$3766.883812105.3210226.284222412.648515820.6996186.12721344.846730942.19185003.85317560.379752331.5193877.304252867.1196$47055.532110825.253711881.3584646.7592404.733811488.3169511381.325419107.77968601.32936686.4313$7740.3371705.6245$2257.4752539556.494510115.008853385.3991517081.089634.53832734.18636082.40512815.4449513616.3586$11163.5681632.56445$2457.211152155.68151261.4422045.68525$27322.73386$2166.73227375.904783490.549118972.49518157.876$20745.98915138.256740720.551059877.607710959.6947$1842.519$5125.2157$7789.6356334.3435519964.74637077.18946948.700821223.675815518.1802536950.256719749.3833821348.70636149.483510450.5525028.146610407.085854830.636128.797452719.27975$4827.90495$13405.39038116.681694.79645246.0472855.4375548824.456455.8626510436.0968823.279$11735.879051631.82124005.4225$7419.477943753.33705$3981.97685325.6516775.9614922.915912557.60534883.8662137.653612044.3421137.46971639.56318516.8299644.252514901.51672130.67598871.151713012.2086537133.89827147.10511743.29920984.09366610.10973537.7035002.78278520.0267371.77210355.6412483.7363392.976825081.767845012.4715253.52434779.61519515.541611987.16822689.495424227.337247358.17565$9225.25647443.6430514001.28671727.7856710.191919444.26581615.766717352.68037152.67145354.0746535160.134577196.86729523.165624476.4785112648.7034$1832.0944040.5582512829.4551$47305.30544260.74994260.74413047.3323543921.18375400.980511520.0998511837.1617085.267624869.8368$36219.4054520462.9976617179.52214590.632057441.0539282.480642856.8387265.7025$9617.662452523.16952803.697852150.46912928.7911$9855.131422331.5668$48549.178354237.1265511879.104059625.927742.10989432.925314256.192847896.791353172.018$20277.807512156.75183906.1271704.568116297.846$21978.6769$9249.49526746.742524873.384912265.506912646.207$19442.353520177.671134151.0287$11944.594358444.4741737.3768124.4084$34838.873$8835.2649510435.065257421.194554667.607654894.7533$35491.6411566.300552866.091$6600.205953561.8889$42760.502247928.03$9144.56548517.5631524393.622413429.035411658.37915$19144.5765213822.803$12142.578613937.666541919.0978232.638818955.2201713352.099813217.094513981.8503510977.20636184.29948334.457555478.03681635.7336511830.6072$8932.0843554.20312404.879114133.0377524603.04837$8944.1151$9620.33071607.510110043.2494751.0713844.5063180.510113430.2658116.268853481.86813415.038112029.2867$7639.4174536085.21918033.967921659.930138126.246516455.7078527000.9847315006.5794542303.6921520781.488925846.91761261.85911856.411530284.64294$3176.81594618.079910736.87075$2138.07078964.06055$9290.1395$7526.706458522.00316586.4977114988.4321631.66839264.79714692.6693510269.463260.1994185.09798539.671$6652.52884074.4537$1621.3402$19594.8096514455.64405$2134.90159140.95118608.262$14418.280428950.469246889.261246599.108439125.332252727.39518968.339788.86596555.07035$7323.7348193167.455854906.40965$5969.72312638.1954243.5900513919.82292254.79675926.84612592.5345$2897.32354738.268237079.3721149.3959$28287.8976626109.3290512730.99965910.9444762.329$7512.2674032.24071969.6141769.531654686.388721797.000411881.969610601.4127682.6710381.4787$22144.03211165.417651632.0362519521.968213224.69312643.377823288.92842201.0971$2497.03832203.471851744.46520878.78443$25382.29728868.663935147.52848253 ...

# %%
insurance_clean["charges"] = insurance_clean["charges"].str.strip("$")
insurance_clean["charges"] = insurance_clean["charges"].astype("float")
assert insurance_clean["charges"].dtype == "float"

# %%
insurance_clean["charges"].dtype
# Out:
# dtype('float64')

# %%
insurance_clean["charges"].describe()
# Out:
# count     1149.000000
# mean     13331.073243
# std      12171.162115
# min       1121.873900
# 25%       4746.344000
# 50%       9541.695550
# 75%      16577.779500
# max      63770.428010
# Name: charges, dtype: float64

# %%
# Getting a csv copy 
insurance_clean.to_csv("insurance_clean.csv")

# %%
insurance_clean.describe()
# Out:
#                age          bmi     children       charges
# count  1149.000000  1149.000000  1149.000000   1149.000000
# mean     39.204526    30.592620     1.017406  13331.073243
# std      14.163214     6.124013     1.192183  12171.162115
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.200000     0.000000   4746.344000
# 50%      39.000000    30.300000     1.000000   9541.695550
# 75%      51.000000    34.700000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ## Model development and training

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split, KFold


# Separating features and target
X = insurance_clean.drop("charges", axis=1)
y = insurance_clean["charges"]

# Identify categorical and numerical columns
categorical_cols = ['sex', 'smoker','region']  
numerical_cols = ["age", "bmi", "children"]  

# Creating the preprocessor
preprocessor = ColumnTransformer(
    transformers=[("num", StandardScaler(), numerical_cols), 
                  ("cat", OneHotEncoder(drop="first"), categorical_cols)])

# %%
# Splitiing the Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=15)

# Create a pipeline that includes both the preprocessor and your model
model = Pipeline(steps=[("preprocessor", preprocessor), 
                        ("regressor", LinearRegression())])

#Performing 
kf = KFold(n_splits=5, shuffle=True, random_state=15)
cv_scores = cross_val_score(model, X_train, y_train,cv=kf, scoring="r2")

# %%
# Print the cross-validation scores
print("Cross-validation R2 scores:", cv_scores)
print("Average R2 score:", cv_scores.mean())
# Out:
# Cross-validation R2 scores: [0.79270508 0.65538464 0.79323295 0.79440822 0.70318542]
# Average R2 score: 0.7477832619660536

# %%
r2_score = cv_scores.mean()

# %%
# Fitting the model
model.fit(X_train, y_train)

# Step 4: Predict on the test set
y_pred = model.predict(X_test)

# Step 5: Evaluate the model's performance on the test set
test_r2_score = model.score(X_test, y_test)
print("Test R2 score:", test_r2_score)
# Out:
# Test R2 score: 0.6816623748250806

# %% [markdown]
# ## Making predictions for new data

# %%
# Loading the Data

validation_data = pd.read_csv("validation_dataset.csv")
validation_data.head()
# Out:
#     age     sex        bmi  children smoker     region
# 0  18.0  female  24.090000       1.0     no  southeast
# 1  39.0    male  26.410000       0.0    yes  northeast
# 2  27.0    male  29.150000       0.0    yes  southeast
# 3  71.0    male  65.502135      13.0    yes  southeast
# 4  28.0    male  38.060000       0.0     no  southeast

# %%
validation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       50 non-null     float64
#  1   sex       50 non-null     object
#  2   bmi       50 non-null     float64
#  3   children  50 non-null     float64
#  4   smoker    50 non-null     object
#  5   region    50 non-null     object
# dtypes: float64(3), object(3)
# memory usage: 2.5+ KB

# %%
validation_data.describe()
# Out:
#              age        bmi   children
# count  50.000000  50.000000  50.000000
# mean   46.820000  39.539907   2.780000
# std    21.681074  17.725844   4.026899
# min    18.000000  18.715000   0.000000
# 25%    28.000000  27.575000   0.000000
# 50%    44.500000  33.807500   1.000000
# 75%    60.750000  40.208750   2.750000
# max    92.000000  89.097296  13.000000

# %% [markdown]
# ## Data Cleaning

# %%
validation_data["age"] = validation_data["age"].astype("int")
validation_data["children"] = validation_data["children"].astype("int")
validation_data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# dtype: object

# %%
validation_data["sex"].value_counts()
# Out:
# female    25
# male      25
# Name: sex, dtype: int64

# %%
validation_data["smoker"].value_counts()
# Out:
# no     32
# yes    18
# Name: smoker, dtype: int64

# %%
validation_data["region"].value_counts()
# Out:
# northwest    16
# southeast    14
# northeast    11
# southwest     9
# Name: region, dtype: int64

# %%
validation_data.describe()
# Out:
#              age        bmi   children
# count  50.000000  50.000000  50.000000
# mean   46.820000  39.539907   2.780000
# std    21.681074  17.725844   4.026899
# min    18.000000  18.715000   0.000000
# 25%    28.000000  27.575000   0.000000
# 50%    44.500000  33.807500   1.000000
# 75%    60.750000  40.208750   2.750000
# max    92.000000  89.097296  13.000000

# %%
validation_data["predicted_charges"] = model.predict(validation_data)
validation_data["predicted_charges"].describe()
# Out:
# count       50.000000
# mean     22736.179180
# std      19974.887155
# min       -318.026961
# 25%       7433.353880
# 50%      13358.676645
# 75%      32323.746332
# max      68043.911924
# Name: predicted_charges, dtype: float64

# %%
validation_data["predicted_charges"] = validation_data["predicted_charges"].clip(lower=1000)
validation_data["predicted_charges"].describe()
# Out:
# count       50.000000
# mean     22800.987604
# std      19900.750612
# min       1000.000000
# 25%       7433.353880
# 50%      13358.676645
# 75%      32323.746332
# max      68043.911924
# Name: predicted_charges, dtype: float64
